# %% [markdown]
# # Analytical methods - bounds and approximations
#
# Created by: Dr. Mauricio Fernández

# %%
# Run this cell first (required for all commands in this notebook)
# %run -i ../scripts/main
# Out:
# Static plot

# %%
# Run this cell to start interactive content
# YOU CAN ONLY USE THE INTERACTIVE CONTENT 
# IF YOU HAVE PYTHON ON YOUR COMPUTER (WITH ALL REQUIRED PACKAGES)
# OR IF YOU OPEN THIS THROUGH BINDER (SEE README OF REPOSITORY).
start_selective()
# Out:
# interactive(children=(Dropdown(description='Select device', index=1, options=(('', 0), ('computer', 1), ('smar…
