# %% [markdown]
# # Analytical methods - bounds and approximations
#
# Creator(s) of content: Dr. Mauricio Fernández

# %%
# %run -i ../scripts/main
# Out:
# Static plot

# %%
start()
# Out:
# Starting interactive plots
# ...
# Button(description='Run/Update', style=ButtonStyle())
# Output()
